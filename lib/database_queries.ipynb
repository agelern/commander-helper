# %%
from dotenv import load_dotenv
import os
from os import environ as env
import psycopg2
import pandas as pd

# %%
# Load environment variables
load_dotenv()
db_user = os.getenv('DB_USER')
db_password = os.getenv('DB_PASSWORD')
db_host = os.getenv('DB_HOST')
db_name = os.getenv('DB_NAME')

# %%
# Connect to my MTG database
conn = psycopg2.connect(
    host=db_host,
    database=db_name,
    user=db_user,
    password=db_password
)

# %%
from sqlalchemy import create_engine


# With the env variables loaded we can insert them into the engine connection string.
engine = create_engine(f"postgresql+psycopg2://{env['DB_USER']}:{env['DB_PASSWORD']}@{env['DB_HOST']}/{env['DB_NAME']}")
connection = engine.connect()

# %%
# Enter list of cards to match to a commander
items = ['Craterhoof Behemoth', 'Zur the Enchanter', 'Lightning Bolt', 'Dino DNA', 'Taniwha', 'Swords to Plowshares', 'Ancient Tomb']

# Create a comma-separated string of items
items_str = "', '".join(items)

query = f"SELECT DISTINCT coloridentity FROM cards WHERE name IN ('{items_str}');"
result_df = pd.read_sql(query, connection)

identities = [x.replace(',', '').replace(' ', '') for x in result_df['coloridentity'] if x != None]
identities_string = ''.join(identities)
command_color = list(''.join(dict.fromkeys(identities_string)))
command_color
# Out:
# ['B', 'U', 'W', 'G', 'R']

# %%
color_conditions = ' AND '.join([f"coloridentity LIKE '%%{color}%%'" for color in command_color])

query = f"""
    SELECT DISTINCT name, edhrecrank, coloridentity, type, text, uuid 
    FROM (
        SELECT *
        FROM cards
        WHERE id in (select min(id) from cards group by name)
    ) unique_names
    WHERE type LIKE '%%Legendary%%Creature%%' 
        AND {color_conditions}
        AND edhrecrank >= 0
    ORDER BY edhrecrank
    LIMIT 100
    """

# Execute the query and store the results in a dataframe
commander_df = pd.read_sql(query, connection)

# Display the resulting dataframe
# commander_df
# Out:
#                                               name  edhrecrank  coloridentity  \
# 0   Esika, God of the Tree // The Prismatic Bridge        1591  B, G, R, U, W
# 1                          Morophon, the Boundless        1649  B, G, R, U, W
# 2                      Sisay, Weatherlight Captain        1884  B, G, R, U, W
# 3                             Ramos, Dragon Engine        2153  B, G, R, U, W
# 4                       Kenrith, the Returned King        2191  B, G, R, U, W
# 5                                    The Ur-Dragon        2266  B, G, R, U, W
# 6                                           Tiamat        2448  B, G, R, U, W
# 7                               Jodah, the Unifier        2450  B, G, R, U, W
# 8                          Jodah, Archmage Eternal        2868  B, G, R, U, W
# 9                                  Sliver Hivelord        3008  B, G, R, U, W
# 10                        Jegantha, the Wellspring        3045  B, G, R, U, W
# 11                     Go-Shintai of Life's Origin        3108  B, G, R, U, W
# 12                                The First Sliver        3153  B, G, R, U, W
# 13                      Najeela, the Blade-Blossom        3453  B, G, R, U, W
# 14                                   Sliver Legion        3498  B, G, R, U, W
# 15                          Scion of the Ur-Dragon        3690  B, G, R, U, W
# 16                                 Sliver Overlord        3902  B, G, R, U, W
# 17                            Omnath, Locus of All        4732  B, G, R, U, W
# 18                        O-Kagachi, Vengeful Kami        4933  B, G, R, U, W
# 19                  Jenson Carthalion, Druid Exile        5013  B, G, R, U, W
# 20                                      Progenitus        5286  B, G, R, U, W
# 21                                   Garth One-Eye        5320  B, G, R, U, W
# 22                      Urtet, Remnant of Memnarch        5729  B, G, R, U, W
# 23                                    Sliver Queen        5736  B, G, R, U, W
# 24                               Niv-Mizzet Reborn        5854  B, G, R, U, W
# 25                                     Reaper King        6332  B, G, R, U, W
# 26                                    Tom Bombadil        6377  B, G, R, U, W
# 27                        Kyodai, Soul of Kamigawa        6591  B, G, R, U, W
# 28                                  Child of Alara        7199  B, G, R, U, W
# 29                         Codie, Vociferous Codex        7660  B, G, R, U, W
# 30                              Sliver Gravemother        7675  B, G, R, U, W
# 31                                Horde of Notions        9179  B, G, R, U, W
# 32                          Tazri, Beacon of Unity        9622  B, G, R, U, W
# 33                               Karona, False God       10610  B, G, R, U, W
# 34                                   General Tazri       10744  B, G, R, U, W
# 35                            Rukarumel, Biologist       11183  B, G, R, U, W
# 36                             Niv-Mizzet, Supreme       11756  B, G, R, U, W
# 37                                          Cromat       11876  B, G, R, U, W
# 38                        Tazri, Stalwart Survivor       14313  B, G, R, U, W
# 39                                        Atogatog       14343  B, G, R, U, W
# 40                        Vorthos, Steward of Myth       21961  B, G, R, U, W
#
#                                         type  \
# 0                   Legendary Creature — God
# 1          Legendary Creature — Shapeshifter
# 2         Legendary Creature — Human Soldier
# 3       Legendary Artifact Creature — Dragon
# 4           Legendary Creature — Human Noble
# 5         Legendary Creature — Dragon Avatar
# 6            Legendary Creature — Dragon God
# 7          Legendary Creature — Human Wizard
# 8          Legendary Creature — Human Wizard
# 9                Legendary Creature — Sliver
# 10        Legendary Creature — Elemental Elk
# 11   Legendary Enchantment Creature — Shrine
# 12               Legendary Creature — Sliver
# 13        Legendary Creature — Human Warrior
# 14               Legendary Creature — Sliver
# 15        Legendary Creature — Dragon Avatar
# 16        Legendary Creature — Sliver Mutant
# 17  Legendary Creature — Phyrexian Elemental
# 18        Legendary Creature — Dragon Spirit
# 19          Legendary Creature — Human Druid
# 20         Legendary Creature — Hydra Avatar
# 21         Legendary Creature — Human Wizard
# 22         Legendary Artifact Creature — Myr
# 23               Legendary Creature — Sliver
# 24        Legendary Creature — Dragon Avatar
# 25   Legendary Artifact Creature — Scarecrow
# 26             Legendary Creature — God Bard
# 27        Legendary Creature — Dragon Spirit
# 28               Legendary Creature — Avatar
# 29   Legendary Artifact Creature — Construct
# 30               Legendary Creature — Sliver
# 31            Legendary Creature — Elemental
# 32        Legendary Creature — Human Warrior
# 33               Legendary Creature — Avatar
# 34           Legendary Creature — Human Ally
# 35         Legendary Creature — Human Wizard
# 36        Legendary Creature — Dragon Avatar
# 37             Legendary Creature — Illusion
# 38        Legendary Creature — Human Warrior
# 39                 Legendary Creature — Atog
# 40          Legendary Creature — Human Gamer
#
#                                                  text  \
# 0   Vigilance\n{T}: Add one mana of any color.\nOt...
# 1   Changeling (This card is every creature type.)...
# 2   Sisay, Weatherlight Captain gets +1/+1 for eac...
# 3   Flying\nWhenever you cast a spell, put a +1/+1...
# 4   {R}: All creatures gain trample and haste unti...
# 5   Eminence — As long as The Ur-Dragon is in the ...
# 6   Flying\nWhen Tiamat enters the battlefield, if...
# 7   Legendary creatures you control get +X/+X, whe...
# 8   Flying\nYou may pay {W}{U}{B}{R}{G} rather tha...
# 9   Sliver creatures you control have indestructib...
# 10  Companion — No card in your starting deck has ...
# 11  {W}{U}{B}{R}{G}, {T}: Return target enchantmen...
# 12  Cascade (When you cast this spell, exile cards...
# 13  Whenever a Warrior attacks, you may have its c...
# 14  All Sliver creatures get +1/+1 for each other ...
# 15  Flying\n{2}: Search your library for a Dragon ...
# 16  {3}: Search your library for a Sliver card, re...
# 17  If you would lose unspent mana, that mana beco...
# 18  Flying, trample\nWhenever O-Kagachi, Vengeful ...
# 19  Whenever you cast a multicolored spell, scry 1...
# 20  Protection from everything\nIf Progenitus woul...
# 21  {T}: Choose a card name that hasn't been chose...
# 22  Whenever you cast a Myr spell, create a 1/1 co...
# 23  {2}: Create a 1/1 colorless Sliver creature to...
# 24  Flying\nWhen Niv-Mizzet Reborn enters the batt...
# 25  ({2/W} can be paid with any two mana or with {...
# 26  As long as there are four or more lore counter...
# 27  Flash\nFlying\nWhen Kyodai, Soul of Kamigawa e...
# 28  Trample\nWhen Child of Alara dies, destroy all...
# 29  You can't cast permanent spells.\n{4}, {T}: Ad...
# 30  The "legend rule" doesn't apply to Slivers you...
# 31  Vigilance, trample, haste\n{W}{U}{B}{R}{G}: Yo...
# 32  This spell costs {1} less to cast for each cre...
# 33  Haste\nAt the beginning of each player's upkee...
# 34  When General Tazri enters the battlefield, you...
# 35  As Rukarumel, Biologist enters the battlefield...
# 36  Flying, hexproof from monocolored\nEach instan...
# 37  {W}{B}: Destroy target creature blocking or bl...
# 38  Each creature you control has "{T}: Add one ma...
# 39  Sacrifice an Atog creature: Atogatog gets +X/+...
# 40  As Vorthos, Steward of Myth enters the battlef...
#
#                                     uuid
# 0   51cea10e-7235-567e-9339-292571210ff5
# 1   2db25501-acbd-5eb3-bf02-20e9aaa3d132
# 2   37a36baf-c9d2-5217-bd74-df614474344c
# 3   606fda89-6450-5902-ba8c-3eb58e34b07e
# 4   b716ea42-01fa-5f8d-af42-efaecf77a748
# 5   7b10747d-fe9c-5ed2-9988-b9c55d41a2da
# 6   e79b9335-6a28-52e2-8758-b150b3568967
# 7   04fae974-50e6-55e2-b05b-a0302b35fc8d
# 8   6b063fe6-b14b-5699-8908-90f0679cbeb3
# 9   b7bd9379-9347-5983-9957-b2d7536c057c
# 10  02a724f6-4a37-5321-81a3-a2fb658b4566
# 11  2b31d20f-3a53-5930-be26-e1a3ccffa958
# 12  485ea57b-16d8-54ba-a84a-c86e57cc70d7
# 13  ec19ecad-a4a6-534d-93b4-2dddea3d2e8a
# 14  1e9dac73-6c4e-5bec-a32c-6d3a76f584e0
# 15  1a621aba-39d6-5b5d-8684-76078a522210
# 16  616f2f27-fd1b-5341-b717-2be62475a53f
# 17  77ff02da-e3e9-5df5-a342-994ac785cfad
# 18  4fd6596a-454b-5988-9286-d2103cf78464
# 19  0deb6ee7-2ef0-5903-8cd4-e0c6450d3262
# 20  83704f1a-b85d-5671-9d82-d6066c01201c
# 21  38f03b7e-f44a-554b-ad1d-c9f4876db2de
# 22  8f33033e-e66f-5690-bdbf-a8054a592918
# 23  19c30231-aeab-50b4-b5fa-9a24c20c3c54
# 24  5507e55e-f034-51f2-8d4c-83008f18a950
# 25  ca0c23c8-93c5-5536-a296-572b95ed2434
# 26  824274bf-fd35-533f-824c-b51480baff76
# 27  8d5cb4ba-2b5e-555a-a03f-34a807ae9505
# 28  1143ffe6-7afe-5fb1-a9fa-3ffa865e4013
# 29  561f39b9-5eef-5dbb-b544-371e237f0db6
# 30  3f469657-c54d-534c-b8f3-28da92a169a6
# 31  73e644a6-5a57-51fe-a000-5ac9dd28bc53
# 32  0776e4ba-ad88-5306-a63e-b3fe54b73753
# 33  d4809483-04f4-5ac9-8cd1-d980405306e8
# 34  1d60cd12-194c-5001-a7fe-4003954bdd46
# 35  0c04a6ce-ddbe-58d5-ae1d-fe31b2174b22
# 36  58b7a3d3-14de-5504-90c8-8d33ed7c2f1c
# 37  1a55f93a-033a-50e7-8b8c-ac66cf4ccdb4
# 38  d6b67e7d-27d7-5074-93e6-ff214bdc6ec6
# 39  7173fffd-c862-527a-83c3-85a104902b8a
# 40  8070623c-6079-5985-a951-000c9a7cb241

# %%
def score(creature_name):
    creature_name = creature_name.lower().replace('[^a-zA-Z0-9]', '').replace(' ', '-').replace(',', '').replace("'", '')
    score = 0
    url = f"https://json.edhrec.com/pages/commanders/{creature_name}.json"
    response = requests.get(url)
    if response.status_code == 200:
        json_data = response.json()
        entered_cards = []  # List to store entered cards that increased the score
        for entered_card in items:
            for edhrec_card in json_data['cardlist']:
                if entered_card == edhrec_card['name']:
                    score += 1
                    if edhrec_card['synergy'] >= 0.3:
                        score += 1
                    if edhrec_card['num_decks'] / edhrec_card['potential_decks'] >= 0.4:
                        score += 1
                    entered_cards.append(entered_card)  # Add entered card to the list
        return score, entered_cards
    else:
        return 0, []

commander_df['score'], commander_df['makesGoodUseOf'] = zip(*commander_df['name'].apply(score))

# %%
commander_df = commander_df.sort_values(['score', 'edhrecrank'], ascending=[False, True])
commander_df = commander_df.reset_index(drop=True)
top_10_df = commander_df[['score', 'edhrecrank', 'name', 'type', 'coloridentity', 'makesGoodUseOf']].head(10)
top_10_df
# Out:
#    score  edhrecrank                         name  \
# 0      5        3108  Go-Shintai of Life's Origin
# 1      3        1649      Morophon, the Boundless
# 2      3        1884  Sisay, Weatherlight Captain
# 3      3        2191   Kenrith, the Returned King
# 4      3        2266                The Ur-Dragon
# 5      3        2450           Jodah, the Unifier
# 6      3        3453   Najeela, the Blade-Blossom
# 7      3        3690       Scion of the Ur-Dragon
# 8      3        5729   Urtet, Remnant of Memnarch
# 9      3        5736                 Sliver Queen
#
#                                       type  coloridentity  \
# 0  Legendary Enchantment Creature — Shrine  B, G, R, U, W
# 1        Legendary Creature — Shapeshifter  B, G, R, U, W
# 2       Legendary Creature — Human Soldier  B, G, R, U, W
# 3         Legendary Creature — Human Noble  B, G, R, U, W
# 4       Legendary Creature — Dragon Avatar  B, G, R, U, W
# 5        Legendary Creature — Human Wizard  B, G, R, U, W
# 6       Legendary Creature — Human Warrior  B, G, R, U, W
# 7       Legendary Creature — Dragon Avatar  B, G, R, U, W
# 8        Legendary Artifact Creature — Myr  B, G, R, U, W
# 9              Legendary Creature — Sliver  B, G, R, U, W
#
#                                    makesGoodUseOf
# 0       [Zur the Enchanter, Swords to Plowshares]
# 1  [Dino DNA, Swords to Plowshares, Ancient Tomb]
# 2            [Swords to Plowshares, Ancient Tomb]
# 3            [Swords to Plowshares, Ancient Tomb]
# 4            [Swords to Plowshares, Ancient Tomb]
# 5            [Swords to Plowshares, Ancient Tomb]
# 6            [Swords to Plowshares, Ancient Tomb]
# 7            [Swords to Plowshares, Ancient Tomb]
# 8            [Swords to Plowshares, Ancient Tomb]
# 9            [Swords to Plowshares, Ancient Tomb]
